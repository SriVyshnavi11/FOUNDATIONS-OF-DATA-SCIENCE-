# %% [markdown]
# <a href="https://colab.research.google.com/github/SriVyshnavi11/FOUNDATIONS-OF-DATA-SCIENCE-/blob/main/FDSLab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
print("First 5 Rows:")
print(df.head())
# Out:
# First 5 Rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print("\nNull Values:")
print(df.isnull().sum())
# Out:
# Null Values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
if df.isnull().sum().sum() == 0:
    print("\nNo null values found. Calculating Central Tendency...\n")

    print("Mean:")
    print(df.mean())

    print("\nMedian:")
    print(df.median())

    print("\nMode:")
    print(df.mode())
else:
    print("\nNull values found. Fill them before calculating central tendency.")
# Out:
# No null values found. Calculating Central Tendency...
#
# Mean:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64
#
# Median:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64
#
# Mode:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.0               3.0                1.4               0.2
# 1                NaN               NaN                1.5               NaN
