# %% [markdown]
# <a href="https://colab.research.google.com/github/SriVyshnavi11/FOUNDATIONS-OF-DATA-SCIENCE-/blob/main/FDSLab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

df = sns.load_dataset("titanic")
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
num_cols = ['age', 'fare']

for col in num_cols:
    data = df[col].dropna()

    print("\nColumn:", col)
    print("Range:", data.max() - data.min())
    print("Variance:", data.var())
    print("Standard Deviation:", data.std())
    print("Interquartile Range (IQR):", data.quantile(0.75) - data.quantile(0.25))
# Out:
# Column: age
# Range: 79.58
# Variance: 211.0191247463081
# Standard Deviation: 14.526497332334044
# Interquartile Range (IQR): 17.875
#
# Column: fare
# Range: 512.3292
# Variance: 2469.436845743117
# Standard Deviation: 49.693428597180905
# Interquartile Range (IQR): 23.0896

# %%
#Take the TITANIC dataset. Apply various measures of dispersion. Plot graphs to study the shape of data distribution.
age = df['age'].dropna()
fare = df['fare'].dropna()

# Create combined figure
fig, ax = plt.subplots(2, 2, figsize=(12, 8))

# Age Histogram
ax[0,0].hist(age, bins=20, color='skyblue', edgecolor='black')
ax[0,0].set_title("Age Histogram")
ax[0,0].set_xlabel("Age")
ax[0,0].set_ylabel("Frequency")

# Fare Histogram
ax[0,1].hist(fare, bins=20, color='lightgreen', edgecolor='black')
ax[0,1].set_title("Fare Histogram")
ax[0,1].set_xlabel("Fare")
ax[0,1].set_ylabel("Frequency")

# Age Box Plot
ax[1,0].boxplot(age)
ax[1,0].set_title("Age Box Plot")
ax[1,0].set_ylabel("Age")

# Fare Box Plot
ax[1,1].boxplot(fare)
ax[1,1].set_title("Fare Box Plot")
ax[1,1].set_ylabel("Fare")

plt.tight_layout()
plt.show()
